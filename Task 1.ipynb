# %% [markdown]
# # Questions on Python Data Types
#
# 1. Create a list containing the numbers 1 to 5. Then:
#    - Append the number 6 to the list.
#    - Replace the second element with the number 10.
#    - Print the list after the changes.
#
# 2. Given the list `my_list = ['apple', 'banana', 'cherry', 'date']`, perform the following:
#    - Access the first element in the list.
#    - Remove the last element from the list.
#    - Insert the string `'grape'` at index 2.
#    - Print the modified list.
#
# 3. Create a set containing the numbers 1, 2, 3, 4. Then:
#    - Add the number 5 to the set.
#    - Try to add the number 3 to the set again. What happens?
#    - Remove the number 2 from the set.
#    - Print the final set.
#
# 4. Given the set `my_set = {'red', 'green', 'blue'}`, perform the following:
#    - Check if `'green'` is present in the set.
#    - Add `'yellow'` to the set.
#    - Remove `'red'` from the set.
#    - Print the modified set.
#
# 5. Create a tuple containing the numbers 1, 2, 3, 4, 5. Then:
#    - Access the third element of the tuple.
#    - Try to modify the second element of the tuple. What happens?
#    - Print the tuple.
#
# 6. Given the tuple `my_tuple = ('apple', 'banana', 'cherry')`, perform the following:
#    - Access the last element in the tuple.
#    - Check if `'banana'` is in the tuple.
#    - Print the tuple.
#
# 7. Create a dictionary with the following key-value pairs: `'name': 'John', 'age': 25, 'city': 'New York'`. Then:
#    - Access the value associated with the key `'name'`.
#    - Change the value of the key `'age'` to 26.
#    - Add a new key `'job'` with the value `'Engineer'`.
#    - Print the modified dictionary.
#
# 8. Given the dictionary `my_dict = {'brand': 'Toyota', 'model': 'Corolla', 'year': 2019}`, perform the following:
#    - Access the value associated with the key `'model'`.
#    - Remove the key `'year'` from the dictionary.
#    - Add a new key `'color'` with the value `'blue'`.
#    - Print the modified dictionary.

# %%
numbers = [1, 2, 3, 4, 5]

# Append 6
numbers.append(6)

# Replace the second element with 10
numbers[1] = 10

# Print the updated list
print("Question 1:", numbers)
# Out:
# Question 1: [1, 10, 3, 4, 5, 6]

# %%
my_list = ['apple', 'banana', 'cherry', 'date']

# Access the first element
print("First element:", my_list[0])

# Remove the last element
my_list.pop()

# Insert 'grape' at index 2
my_list.insert(2, 'grape')

# Print the modified list
print("Question 2:", my_list)
# Out:
# First element: apple
# Question 2: ['apple', 'banana', 'grape', 'cherry']

# %%
# 3. Set Operations
# =========================

my_set = {1, 2, 3, 4}

# Add 5
my_set.add(5)

# Try to add 3 again
my_set.add(3)  # No change because sets do not allow duplicates

# Remove 2
my_set.remove(2)

# Print the final set
print("Question 3:", my_set)
# Out:
# Question 3: {1, 3, 4, 5}

# %%
# 4. Set Operations
# =========================

my_set = {'red', 'green', 'blue'}

# Check if 'green' exists
print("'green' in set:", 'green' in my_set)

# Add 'yellow'
my_set.add('yellow')

# Remove 'red'
my_set.remove('red')

# Print the modified set
print("Question 4:", my_set)
# Out:
# 'green' in set: True
# Question 4: {'blue', 'green', 'yellow'}

# %%
# 5. Tuple Operations
# =========================

my_tuple = (1, 2, 3, 4, 5)

# Access the third element
print("Third element:", my_tuple[2])

# Try to modify the second element
try:
    my_tuple[1] = 10
except TypeError as e:
    print("Error:", e)

# Print the tuple
print("Question 5:", my_tuple)
# Out:
# Third element: 3
# Error: 'tuple' object does not support item assignment
# Question 5: (1, 2, 3, 4, 5)

# %%
# 6. Tuple Operations
# =========================

my_tuple = ('apple', 'banana', 'cherry')

# Access the last element
print("Last element:", my_tuple[-1])

# Check if 'banana' is in the tuple
print("'banana' in tuple:", 'banana' in my_tuple)

# Print the tuple
print("Question 6:", my_tuple)
# Out:
# Last element: cherry
# 'banana' in tuple: True
# Question 6: ('apple', 'banana', 'cherry')

# %%
# 7. Dictionary Operations
# =========================

person = {
    'name': 'John',
    'age': 25,
    'city': 'New York'
}

# Access the value of 'name'
print("Name:", person['name'])

# Update age
person['age'] = 26

# Add a new key-value pair
person['job'] = 'Engineer'

# Print the modified dictionary
print("Question 7:", person)
# Out:
# Name: John
# Question 7: {'name': 'John', 'age': 26, 'city': 'New York', 'job': 'Engineer'}

# %%
# =========================
# 8. Dictionary Operations
# =========================

my_dict = {
    'brand': 'Toyota',
    'model': 'Corolla',
    'year': 2019
}

# Access the value of 'model'
print("Model:", my_dict['model'])

# Remove 'year'
my_dict.pop('year')

# Add 'color'
my_dict['color'] = 'blue'

# Print the modified dictionary
print("Question 8:", my_dict)
# Out:
# Model: Corolla
# Question 8: {'brand': 'Toyota', 'model': 'Corolla', 'color': 'blue'}
